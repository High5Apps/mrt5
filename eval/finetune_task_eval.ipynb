# %%
import pandas as pd

# %%
def compute_weighted_averages(df, split_col='Split'):
    # Compute the total size
    total_size = df['Size'].sum()
    
    # Calculate the weighted averages for each metric
    weighted_averages = {}
    for col in df.columns[1:-1]:  # Exclude 'Split' and 'Size' columns
        weighted_averages[col] = (df[col] * df['Size']).sum() / total_size
    
    # Create a new row for the 'total' split with the weighted averages
    total_row = pd.DataFrame({split_col: ['total'], **weighted_averages, 'Size': [total_size]})
    
    # Append the total row to the dataframe using concat
    df_total = pd.concat([df, total_row], ignore_index=True)
    
    return df_total

# %% [markdown]
# ## Spelling Correction Task

# %%
path = 'eval_results/character_tasks/spelling_correction_contextual/{}/{}.csv'

# ByT5 DF
byt5 = pd.read_csv(path.format('T5', 't5_spelling_correction_contextual_seed83'))
byt5 = compute_weighted_averages(byt5)

# MrT5 DF
mrt5 = pd.read_csv(path.format('MrT5', 'mrt5_spelling_correction_contextual_seed79'))
mrt5 = compute_weighted_averages(mrt5)

# BPT5 DF (50%)
bpt5_50 = pd.read_csv(path.format('BPT5', 'bpt5_spelling_correction_contextual_prior50%_seed960'))
bpt5_50 = compute_weighted_averages(bpt5_50)

# BPT5 DF (70%)
bpt5_70 = pd.read_csv(path.format('BPT5', 'bpt5_spelling_correction_contextual_prior70%_seed960'))
bpt5_70 = compute_weighted_averages(bpt5_70)

# %%
byt5
# Out:
#                       Split  Eval Sequence Accuracy  \
# 0    test_context_dependent               37.627714
# 1  test_context_independent               76.452153
# 2                     total               58.185184
#
#    Eval Percent Deleted Tokens  Eval Runtime  Size
# 0                          0.0      2.386370  4163
# 1                          0.0      2.370906  4685
# 2                          0.0      2.378182  8848

# %%
mrt5
# Out:
#                       Split  Eval Sequence Accuracy  \
# 0    test_context_dependent               35.049489
# 1  test_context_independent               74.755513
# 2                     total               56.073757
#
#    Eval Percent Deleted Tokens  Eval Runtime  Size
# 0                    78.768826      1.457101  4163
# 1                    78.975504      1.392135  4685
# 2                    78.878262      1.422702  8848

# %%
bpt5_50
# Out:
#                       Split  Eval Sequence Accuracy  \
# 0    test_context_dependent               34.921775
# 1  test_context_independent               73.295156
# 2                     total               55.240411
#
#    Eval Percent Deleted Tokens  Eval Runtime  Size
# 0                    50.243330      1.840285  4163
# 1                    50.200927      1.782003  4685
# 2                    50.220878      1.809424  8848

# %%
bpt5_70
# Out:
#                       Split  Eval Sequence Accuracy  \
# 0    test_context_dependent               33.205619
# 1  test_context_independent               71.290037
# 2                     total               53.371250
#
#    Eval Percent Deleted Tokens  Eval Runtime  Size
# 0                    70.193018      2.462491  4163
# 1                    70.252788      1.531087  4685
# 2                    70.224666      1.969314  8848

# %%
(mrt5['Eval Runtime'] - byt5['Eval Runtime']) / byt5['Eval Runtime']
# Out:
# 0   -0.389407
# 1   -0.412826
# 2   -0.401769
# Name: Eval Runtime, dtype: float64

# %%
(bpt5['Eval Runtime'] - byt5['Eval Runtime']) / byt5['Eval Runtime']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 (bpt5['Eval Runtime'] - byt5['Eval Runtime']) / byt5['Eval Runtime']
#
# NameError: name 'bpt5' is not defined

# %% [markdown]
# ## Word Search Task

# %%
path = 'eval_results/character_tasks/word_search/{}/{}.csv'

# ByT5 DF
byt5 = pd.read_csv(path.format('T5', 't5_word_search_seed82'))
byt5 = compute_weighted_averages(byt5)

# MrT5 DF
mrt5 = pd.read_csv(path.format('MrT5', 'mrt5_word_search_seed839'))
mrt5 = compute_weighted_averages(mrt5)

# BPT5 DF (30%)
bpt5_30 = pd.read_csv(path.format('BPT5', 'bpt5_word_search_prior30%_seed45'))
bpt5_30 = compute_weighted_averages(bpt5_30)

# BPT5 DF (30%)
bpt5_70 = pd.read_csv(path.format('BPT5', 'bpt5_word_search_prior70%_seed45'))
bpt5_70 = compute_weighted_averages(bpt5_70)

# %%
byt5
# Out:
#                      Split  Eval Sequence Accuracy  \
# 0                 test_oov               78.052326
# 1          test_paraphrase               83.665835
# 2             test_overlap               77.580409
# 3  test_paraphrase_overlap               58.455882
# 4                    total               75.373972
#
#    Eval Percent Deleted Tokens  Eval Runtime   Size
# 0                          0.0      5.046972   1367
# 1                          0.0      4.729870   6404
# 2                          0.0      4.762386   5466
# 3                          0.0      4.776801   4068
# 4                          0.0      4.776222  17305

# %%
mrt5
# Out:
#                      Split  Eval Sequence Accuracy  \
# 0                 test_oov               79.993771
# 1          test_paraphrase               82.060474
# 2             test_overlap               76.217105
# 3  test_paraphrase_overlap               57.598039
# 4                    total               74.300970
#
#    Eval Percent Deleted Tokens  Eval Runtime   Size
# 0                    72.515522      2.562451   1367
# 1                    72.270892      2.190388   6404
# 2                    76.143810      2.214819   5466
# 3                    73.951910      2.250237   4068
# 4                    73.908694      2.241565  17305

# %%
bpt5_30
# Out:
#                      Split  Eval Sequence Accuracy  \
# 0                 test_oov               59.696844
# 1          test_paraphrase               19.155237
# 2             test_overlap               74.093567
# 3  test_paraphrase_overlap               14.754902
# 4                    total               38.676342
#
#    Eval Percent Deleted Tokens  Eval Runtime   Size
# 0                    20.751872      3.618925   1367
# 1                    21.504710      3.339697   6404
# 2                    22.469333      3.495700   5466
# 3                    21.533969      3.640229   4068
# 4                    21.756806      3.481678  17305

# %%
bpt5_70
# Out:
#                      Split  Eval Sequence Accuracy  \
# 0                 test_oov               38.818522
# 1          test_paraphrase                3.678304
# 2             test_overlap               54.707602
# 3  test_paraphrase_overlap                3.137255
# 4                    total               22.445240
#
#    Eval Percent Deleted Tokens  Eval Runtime   Size
# 0                    78.365977      2.064622   1367
# 1                    78.315442      1.747434   6404
# 2                    75.835703      1.934376   5466
# 3                    78.199870      1.892742   4068
# 4                    77.509009      1.865697  17305

# %%
(mrt5['Eval Runtime'] - byt5['Eval Runtime']) / byt5['Eval Runtime']
# Out:
# 0   -0.492280
# 1   -0.536903
# 2   -0.534935
# 3   -0.528924
# 4   -0.530682
# Name: Eval Runtime, dtype: float64

# %% [markdown]
# ## XNLI

# %%
xnli_size = 5010

# %%
path = 'eval_results/xnli/{}/{}.csv'

# ByT5 DF
byt5 = pd.read_csv(path.format('T5', 't5_xnli_seed98'))
byt5 = byt5.drop(columns='Language Code')
byt5 = compute_weighted_averages(byt5, split_col='Language')

# MrT5 DF
mrt5 = pd.read_csv(path.format('MrT5', 'mrt5_xnli_seed73'))
mrt5 = mrt5.drop(columns='Language Code')
mrt5 = compute_weighted_averages(mrt5, split_col='Language')

# BPT5
bpt5 = pd.read_csv(path.format('BPT5', 'bpt5_xnli_prior50%_seed73'))
bpt5 = bpt5.drop(columns='Language Code')
bpt5 = compute_weighted_averages(bpt5, split_col='Language')

# %%
byt5
# Out:
#       Language  Eval Sequence Accuracy  Eval Percent Deleted Tokens  \
# 0      English               76.472930                          0.0
# 1       French               53.901274                          0.0
# 2      Spanish               55.991242                          0.0
# 3       German               45.680732                          0.0
# 4        Greek               52.010350                          0.0
# 5    Bulgarian               56.309713                          0.0
# 6      Russian               55.354299                          0.0
# 7      Turkish               44.864650                          0.0
# 8       Arabic               51.890924                          0.0
# 9   Vietnamese               48.626592                          0.0
# 10        Thai               48.347930                          0.0
# 11     Chinese               50.696656                          0.0
# 12       Hindi               43.869427                          0.0
# 13     Swahili               40.644904                          0.0
# 14        Urdu               45.481688                          0.0
# 15       total               51.342887                          0.0
#
#     Eval Runtime   Size
# 0       8.902678   5010
# 1      10.701394   5010
# 2      10.107771   5010
# 3      10.416175   5010
# 4      19.023875   5010
# 5      17.539380   5010
# 6      17.965874   5010
# 7       9.710111   5010
# 8      14.064874   5010
# 9      12.564745   5010
# 10     25.226720   5010
# 11      7.929854   5010
# 12     24.433490   5010
# 13      9.057497   5010
# 14     15.590763   5010
# 15     14.215680  75150

# %%
mrt5
# Out:
#       Language  Eval Sequence Accuracy  Eval Percent Deleted Tokens  \
# 0      English               78.841561                    52.561442
# 1       French               51.890924                    47.579790
# 2      Spanish               53.960987                    50.670281
# 3       German               45.939490                    47.605549
# 4        Greek               52.746815                    54.794956
# 5    Bulgarian               53.622611                    47.816622
# 6      Russian               55.971338                    47.947454
# 7      Turkish               42.914013                    46.717308
# 8       Arabic               47.133758                    43.781649
# 9   Vietnamese               47.511943                    46.506110
# 10        Thai               44.068471                    61.066852
# 11     Chinese               50.437898                    24.959770
# 12       Hindi               40.246815                    43.557688
# 13     Swahili               38.614650                    48.480114
# 14        Urdu               40.883758                    38.322608
# 15       total               49.652335                    46.824546
#
#     Eval Runtime   Size
# 0       9.101400   5010
# 1      11.636156   5010
# 2      10.911014   5010
# 3      11.356815   5010
# 4      21.697811   5010
# 5      20.095207   5010
# 6      20.719825   5010
# 7      10.777101   5010
# 8      16.027241   5010
# 9      14.103683   5010
# 10     28.464510   5010
# 11      8.466150   5010
# 12     27.530821   5010
# 13      9.884497   5010
# 14     17.738140   5010
# 15     15.900691  75150

# %%
bpt5
# Out:
#       Language  Eval Sequence Accuracy  Eval Percent Deleted Tokens  \
# 0      English               71.476911                    52.022313
# 1       French               47.173567                    52.890644
# 2      Spanish               51.174363                    53.161599
# 3       German               41.878981                    52.797613
# 4        Greek               43.789809                    55.633176
# 5    Bulgarian               46.118631                    47.812433
# 6      Russian               43.610669                    48.568253
# 7      Turkish               40.684713                    51.864318
# 8       Arabic               42.257166                    56.649906
# 9   Vietnamese               46.078822                    51.925770
# 10        Thai               40.226911                    48.537855
# 11     Chinese               40.724522                    53.759617
# 12       Hindi               39.908439                    46.297631
# 13     Swahili               42.376592                    52.992228
# 14        Urdu               38.972930                    55.776825
# 15       total               45.096868                    52.046012
#
#     Eval Runtime   Size
# 0       4.565122   5010
# 1       5.474971   5010
# 2       5.311914   5010
# 3       5.618026   5010
# 4       9.559969   5010
# 5       9.817064   5010
# 6      10.008446   5010
# 7       5.444286   5010
# 8       6.973733   5010
# 9       6.703267   5010
# 10     13.715584   5010
# 11      4.459494   5010
# 12     13.625900   5010
# 13      5.024393   5010
# 14      7.788674   5010
# 15      7.606056  75150

# %%
(mrt5['Eval Runtime'] - byt5['Eval Runtime']) / byt5['Eval Runtime'] * -100
# Out:
# 0     -2.232160
# 1     -8.734952
# 2     -7.946784
# 3     -9.030566
# 4    -14.055683
# 5    -14.571937
# 6    -15.328788
# 7    -10.988437
# 8    -13.952260
# 9    -12.248069
# 10   -12.834763
# 11    -6.762990
# 12   -12.676581
# 13    -9.130555
# 14   -13.773388
# 15   -11.853187
# Name: Eval Runtime, dtype: float64
